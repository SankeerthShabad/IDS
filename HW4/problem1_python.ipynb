# %%
#Importing csv file as Adult_trainingDF

import pandas as pd
Adult_trainingDF= pd.read_csv("https://raw.githubusercontent.com/SankeerthShabad/IDS/main/HW4/adult_training.csv");
Adult_trainingDF
# Out:
#        age         workclass  education          maritalstatus  \
# 0       50  Self-emp-not-inc         13     Married-civ-spouse
# 1       38           Private          9               Divorced
# 2       49           Private          5  Married-spouse-absent
# 3       52  Self-emp-not-inc          9     Married-civ-spouse
# 4       31           Private         14          Never-married
# ...    ...               ...        ...                    ...
# 14792   43  Self-emp-not-inc         10     Married-civ-spouse
# 14793   32           Private          6     Married-civ-spouse
# 14794   32           Private         14          Never-married
# 14795   58           Private          9                Widowed
# 14796   22           Private          9          Never-married
#
#               occupation     sex  capitalgain  capitalloss income
# 0        Exec-managerial    Male            0            0  <=50K
# 1      Handlers-cleaners    Male            0            0  <=50K
# 2          Other-service  Female            0            0  <=50K
# 3        Exec-managerial    Male            0            0   >50K
# 4         Prof-specialty  Female        14084            0   >50K
# ...                  ...     ...          ...          ...    ...
# 14792       Craft-repair    Male            0            0  <=50K
# 14793  Handlers-cleaners    Male            0            0  <=50K
# 14794       Tech-support    Male            0            0  <=50K
# 14795       Adm-clerical  Female            0            0  <=50K
# 14796       Adm-clerical    Male            0            0  <=50K
#
# [14797 rows x 9 columns]

# %% [markdown]
# ### The csv file was imported as a dataframe named Adult trainingDF, and there are 14797 rows and 9 columns in the dataframe.

# %% [markdown]
# ###The following syntax is used to check for any null values in the Adult trainingDF.

# %%
#To find null or missing values

Adult_trainingDF.isnull().sum()
# Out:
# age              0
# workclass        0
# education        0
# maritalstatus    0
# occupation       0
# sex              0
# capitalgain      0
# capitalloss      0
# income           0
# dtype: int64

# %% [markdown]
# ### We can also observe that there are no null values in Adult trainingDF.

# %% [markdown]
# ## The value counts() method is tested using the syntax shown below.

# %%
#value_counts() for workclass
Adult_trainingDF.workclass.value_counts()
# Out:
# Private             10281
# Self-emp-not-inc     1170
# Local-gov             969
# ?                     829
# State-gov             586
# Self-emp-inc          498
# Federal-gov           454
# Without-pay             5
# Never-worked            5
# Name: workclass, dtype: int64

# %% [markdown]
# ### Because there is an undefined workclass '?', we must replace that undefined value with the most common workclass.

# %% [markdown]
# ## Undefined workclasses are being replaced with the most prevalent workclasses.

# %%
#replacing to most common workclass
Adult_trainingDF['workclass']= Adult_trainingDF['workclass'].replace('?','Private')
Adult_trainingDF.workclass.value_counts()
# Out:
# Private             11110
# Self-emp-not-inc     1170
# Local-gov             969
# State-gov             586
# Self-emp-inc          498
# Federal-gov           454
# Without-pay             5
# Never-worked            5
# Name: workclass, dtype: int64

# %% [markdown]
# ### After converting an undefined work class to a Private, we can observe that the range of Private work class has increased.

# %% [markdown]
# # **CONTINGENCY TABLE**
# *  A contingency table is a tabular representation of categorical data.
# *  A contingency table usually shows frequencies for particular combinations of values of two discrete random variable s X and Y.

# %%
# Cross tabulation of workclass and sex

p_crosstab = pd.crosstab(Adult_trainingDF.workclass, Adult_trainingDF.sex)
print(p_crosstab)
# Out:
# sex               Female  Male
# workclass
# Federal-gov          149   305
# Local-gov            377   592
# Never-worked           1     4
# Private             3951  7159
# Self-emp-inc          54   444
# Self-emp-not-inc     178   992
# State-gov            201   385
# Without-pay            1     4

# %% [markdown]
# ### We discovered that the number of males and females working in various job classes after completing cross tabulation for workclass and sex. We can observe from the crosstabulation above that the private workclass has a greater percentage of working persons. Without-pay and Never-worked workers make up the smallest percentage of the workforce.

# %% [markdown]
# ## Barplot for workclass and sex

# %%
# Creating barplot for work class and sex
# x label rotation

barplot = p_crosstab.plot.bar(rot=50)

# %% [markdown]
# ### The barplot diagram for workclass and sex is seen in the diagram above. Workclass values are on the x axis, while the range of male and female work under each job class is on the y axis.

# %% [markdown]
# ## Contengency table for marital status and sex

# %%
# Cross tabulation of marital status and sex

p_crosstab = pd.crosstab(Adult_trainingDF.maritalstatus, Adult_trainingDF.sex)
print(p_crosstab)
# Out:
# sex                    Female  Male
# maritalstatus
# Divorced                 1219   795
# Married-AF-spouse           7     4
# Married-civ-spouse        761  6010
# Married-spouse-absent      95   104
# Never-married            2160  2717
# Separated                 290   182
# Widowed                   380    73

# %% [markdown]
# ### Marital status and sex are compared in a cross-tabulation. This crosstab displays the entire male and female population by marital status. Females have the largest number of married-civ-spouses, whereas males have the highest number of married-civ-spouses.

# %% [markdown]
# ## Barplot for sex and marital status

# %%
# Creating barplot for sex and marital status
# x label rotation

barplot = p_crosstab.plot.bar(rot=50)

# %% [markdown]
# ### For marital status and sex, a barplot diagram is used. Male and female values are on the x axis, while the range of male and female marital status is on the y axis. Married-civ-spouse has the highest marital status, while Married-AF-spouse has the lowest.

# %% [markdown]
# ## Creating new data frame

# %%
#creating new dataframe for age>40
adultabove40DF= Adult_trainingDF[Adult_trainingDF['age']>40]
adultabove40DF
# Out:
#        age         workclass  education          maritalstatus  \
# 0       50  Self-emp-not-inc         13     Married-civ-spouse
# 2       49           Private          5  Married-spouse-absent
# 3       52  Self-emp-not-inc          9     Married-civ-spouse
# 7       43           Private          7     Married-civ-spouse
# 8       54           Private         10     Married-civ-spouse
# ...    ...               ...        ...                    ...
# 14787   45         Local-gov         12               Divorced
# 14790   65  Self-emp-not-inc         15          Never-married
# 14791   43         State-gov         10               Divorced
# 14792   43  Self-emp-not-inc         10     Married-civ-spouse
# 14795   58           Private          9                Widowed
#
#              occupation     sex  capitalgain  capitalloss income
# 0       Exec-managerial    Male            0            0  <=50K
# 2         Other-service  Female            0            0  <=50K
# 3       Exec-managerial    Male            0            0   >50K
# 7      Transport-moving    Male            0         2042  <=50K
# 8                     ?    Male            0            0   >50K
# ...                 ...     ...          ...          ...    ...
# 14787    Prof-specialty  Female            0            0  <=50K
# 14790    Prof-specialty    Male         1086            0  <=50K
# 14791      Adm-clerical  Female            0            0  <=50K
# 14792      Craft-repair    Male            0            0  <=50K
# 14795      Adm-clerical  Female            0            0  <=50K
#
# [6144 rows x 9 columns]

# %% [markdown]
# ### For persons over the age of 40, a dataframe called 'Adultabove40' was created.

# %% [markdown]
# ## Contengency table for marital status and sex

# %%
# Creating contingency table for age above 40
p_crosstab = pd.crosstab(adultabove40DF.maritalstatus, adultabove40DF.sex)

print(p_crosstab)
# Out:
# sex                    Female  Male
# maritalstatus
# Divorced                  720   448
# Married-civ-spouse        305  3383
# Married-spouse-absent      38    47
# Never-married             256   315
# Separated                 133    74
# Widowed                   354    71

# %% [markdown]
# ### Adultabove40DF contingency table Females are more likely to be divorced, whereas males are more likely to be married-civil-spouse.

# %% [markdown]
# ## Barplot for sex and marital status

# %%
# Creating barplot fro adult over 40
# x label rotation

barplot = p_crosstab.plot.bar(rot=50)

# %% [markdown]
# ### Adultover40's barplot. Males over 40 have a greater range in Married-civ-spouse in marital status, while female divorced have a higher range in marital status, as seen in the graph above.

# %% [markdown]
# # Detecting Outliers for education

# %%
#Outlier for education

import seaborn as sns
sns.boxplot(Adult_trainingDF['education'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# Outliers from 4 are plainly seen in the graph above.

# %% [markdown]
# ### Identifying the outliers with a value of less than 4

# %%
# Position of the Outlier
import numpy as np
print(np.where(Adult_trainingDF['education']<=4))
# Out:
# (array([   72,    96,   101,   199,   234,   243,   252,   284,   294,
#          305,   353,   424,   437,   480,   541,   627,   641,   721,
#          762,   785,   820,   834,   843,   877,   937,   946,   996,
#         1030,  1068,  1097,  1103,  1123,  1157,  1182,  1195,  1211,
#         1222,  1223,  1285,  1308,  1312,  1318,  1321,  1350,  1396,
#         1474,  1478,  1482,  1485,  1496,  1517,  1519,  1569,  1587,
#         1606,  1646,  1647,  1667,  1683,  1724,  1741,  1783,  1807,
#         1865,  1880,  1983,  2063,  2093,  2179,  2286,  2295,  2299,
#         2311,  2326,  2343,  2351,  2372,  2395,  2397,  2447,  2456,
#         2465,  2523,  2538,  2544,  2578,  2587,  2626,  2640,  2685,
#         2702,  2746,  2757,  2880,  2894,  2936,  2978,  3050,  3104,
#         3141,  3184,  3199,  3216,  3222,  3261,  3273,  3296,  3372,
#         3506,  3524,  3558,  3571,  3593,  3624,  3638,  3647,  3650,
#         3685,  3698,  3723,  3732,  3741,  3785,  3817,  3837,  3866,
#         3891,  3924,  3967,  4039,  4042,  4060,  4078,  4079,  4080,
#         4125,  4128,  4136,  4188,  4223,  4240,  4256,  4276,  4301,
#         4313,  4318,  4390,  4411,  4415,  4488,  4574,  4590,  4643,
#         4660,  4715,  4721,  4759,  4761,  4804,  4811,  4827,  4876,
#         4886,  4925,  4970,  4973,  5000,  5019,  5035,  5043,  5046,
#         5097,  5105,  5162,  5178,  5213,  5240,  5246,  5262,  5273,
#         5291,  5305,  5336,  5378,  5431,  5444,  5456,  5493,  5496,
#         5524,  5531,  5540,  5585,  5594,  5625,  5645,  5659,  5660,
#         5677,  5689,  5702,  5761,  5841,  5848,  5872,  5959,  5961,
#         5966,  5979,  5985,  5988,  5989,  6002,  6008,  6024,  6048,
#         6102,  6166,  6167,  6201,  6225,  6258,  6272,  6288,  6327,
#         6380,  6391,  6447,  6460,  6490,  6506,  6508,  6514,  6529,
#         6554,  6611,  6642,  6659,  6717,  6784,  6788,  6792,  6796,
#         6798,  6843,  6848,  6849,  6910,  6947,  6991,  7002,  7090,
#         7095,  7105,  7223,  7226,  7231,  7233,  7281,  7307,  7325,
#         7338,  7353,  7378,  7385,  7420,  7456,  7464,  7508,  7512,
#         7523,  7564,  7580,  7585,  7666,  7680,  7699,  7751,  7761,
#         7783,  7815,  7867,  7890,  7905,  7925,  7941,  7944,  7962,
#         8003,  8035,  8046,  8071,  8080,  8094,  8131,  8180,  8192,
#         8195,  8305,  8354,  8372,  8394,  8433,  8452,  8466,  8514,
#         8538,  8542,  8576,  8663,  8664,  8681,  8722,  8740,  8754,
#         8765,  8772,  8880,  8963,  8969,  8974,  9134,  9157,  9164,
#         9181,  9190,  9223,  9226,  9243,  9248,  9316,  9358,  9367,
#         9369,  9398,  9511,  9533,  9549,  9562,  9570,  9663,  9680,
#         9683,  9687,  9693,  9695,  9716,  9746,  9751,  9774,  9784,
#         9803,  9831,  9840,  9863,  9874,  9905,  9949,  9965,  9974,
#         9975,  9988, 10006, 10026, 10092, 10131, 10148, 10211, 10214,
#        10229, 10264, 10316, 10396, 10418, 10453, 10470, 10511, 10518,
#        10545, 10546, 10579, 10598, 10599, 10603, 10614, 10651, 10705,
#        10716, 10719, 10817, 10844, 10849, 10874, 10876, 10891, 10940,
#        11002, 11050, 11067, 11091, 11097, 11108, 11125, 11144, 11177,
#        11213, 11249, 11328, 11481, 11483, 11484, 11497, 11509, 11510,
#        11531, 11550, 11562, 11577, 11590, 11654, 11682, 11693, 11741,
#        11794, 11801, 11802, 11804, 11823, 11903, 11912, 11946, 11959,
#        11981, 12038, 12061, 12076, 12148, 12155, 12182, 12197, 12223,
#        12252, 12264, 12295, 12332, 12342, 12357, 12398, 12453, 12487,
#        12489, 12498, 12508, 12534, 12542, 12559, 12565, 12570, 12615,
#        12619, 12631, 12644, 12656, 12682, 12714, 12734, 12744, 12745,
#        12756, 12764, 12790, 12796, 12828, 12835, 12837, 12869, 12891,
#        12955, 12962, 12965, 12972, 12997, 13001, 13004, 13006, 13064,
#        13067, 13081, 13083, 13104, 13148, 13161, 13168, 13205, 13218,
#        13229, 13265, 13294, 13365, 13370, 13373, 13382, 13391, 13396,
#        13446, 13455, 13486, 13511, 13552, 13563, 13673, 13708, 13746,
#        13750, 13758, 13763, 13782, 13824, 13836, 13852, 13895, 13930,
#        14011, 14015, 14016, 14049, 14082, 14087, 14097, 14116, 14141,
#        14185, 14252, 14254, 14296, 14318, 14330, 14411, 14455, 14475,
#        14497, 14549, 14551, 14572, 14584, 14624, 14690, 14723, 14724,
#        14727, 14742, 14759]),)

# %% [markdown]
# ### Outliers indexing numbers where education<4.

# %% [markdown]
# ## Describe() method

# %%
#Using describe() function

Adult_trainingDF['education'].describe()
# Out:
# count    14797.000000
# mean        10.068798
# std          2.598297
# min          1.000000
# 25%          9.000000
# 50%         10.000000
# 75%         12.000000
# max         16.000000
# Name: education, dtype: float64

# %% [markdown]
# ### describe() returns the count, mean, standard deviation, min, quartiles, and maximum values for the specified dataframe.

# %% [markdown]
# ## Identifying lower and upper limit outliers

# %%
# finding upper and lower bound of age

q1=Adult_trainingDF['education'].quantile(0.25)
q3=Adult_trainingDF['education'].quantile(0.75)
iqr=q3-q1
edu_lower_bound=Adult_trainingDF['education'][Adult_trainingDF['education']<q1-(1.5 * iqr)]
edu_upper_bound=Adult_trainingDF['education'][Adult_trainingDF['education']>q3 +(1.5 * iqr)]

# %%
edu_lower_bound
# Out:
# 72       2
# 96       4
# 101      1
# 199      2
# 234      3
#         ..
# 14723    4
# 14724    2
# 14727    3
# 14742    4
# 14759    4
# Name: education, Length: 552, dtype: int64

# %%
edu_upper_bound
# Out:
# Series([], Name: education, dtype: int64)

# %%
min(edu_lower_bound)
# Out:
# 1

# %% [markdown]
# ## In education, there are several outliers in the lower bound and none in the upper bound. and the most extreme educational outlier is 1.

# %% [markdown]
# # Zscore for age

# %%
#zscore for age in Adult_training
from scipy import stats
zscore = stats.zscore(Adult_trainingDF.age)
zscore
# Out:
# array([ 0.82703775, -0.05025705,  0.75392985, ..., -0.48890445,
#         1.41190094, -1.21998344])

# %% [markdown]
# ### In adult trainingDF, we can see the zscored values of age.

# %% [markdown]
# # Detecting Outliers for age

# %%
#ploting Outliers for age 

sns.boxplot(Adult_trainingDF['age'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# ### Outliers from 80 can be seen from the above plot

# %% [markdown]
# ## Finding positions of outliers

# %%
#Postions of outliers

import numpy as np
print(np.where(Adult_trainingDF['age']>80))
# Out:
# (array([   99,   492,   552,   885,  1066,  1485,  2420,  2467,  2877,
#         3453,  3868,  3891,  4114,  4680,  5154,  5481,  5936,  5961,
#         6476,  7147,  7254,  7651,  8405,  8608,  8768,  8773,  8785,
#         8921,  9369,  9397,  9561,  9857, 10158, 10282, 10468, 10470,
#        10991, 11091, 11108, 11234, 11562, 12656, 12948, 13455, 14091,
#        14281, 14471, 14660, 14746, 14766]),)

# %% [markdown]
# # Describe() method

# %%
#Using describe() function

Adult_trainingDF['age'].describe()
# Out:
# count    14797.000000
# mean        38.687437
# std         13.678875
# min         17.000000
# 25%         28.000000
# 50%         37.000000
# 75%         48.000000
# max         90.000000
# Name: age, dtype: float64

# %% [markdown]
# ### describe() returns the count, mean, standard deviation, min, quartiles, and maximum values for the specified dataframe.

# %% [markdown]
# ## Identifying lower and upper limit outliers

# %%
# finding upper and lower bound of age

Q1=Adult_trainingDF['age'].quantile(0.25)
Q3=Adult_trainingDF['age'].quantile(0.75)
IQR=Q3-Q1
lower_bound=Adult_trainingDF['age'][Adult_trainingDF['age']<Q1-(1.5 * IQR)]
upper_bound=Adult_trainingDF['age'][Adult_trainingDF['age']>Q3 +(1.5 * IQR)]

# %%
upper_bound
# Out:
# 30       79
# 99       90
# 204      80
# 492      90
# 552      88
#          ..
# 14455    80
# 14471    82
# 14660    90
# 14746    85
# 14766    82
# Name: age, Length: 70, dtype: int64

# %%
lower_bound
# Out:
# Series([], Name: age, dtype: int64)

# %%
max(upper_bound)
# Out:
# 90

# %% [markdown]
# ## In education, there are no outliers lower bound and several outliers in the upper bound. and the most extreme educational outlier is 90.

# %% [markdown]
# # Density ploting for age

# %%
#Ploting Density of outiliers for age

from scipy import stats
import matplotlib.pyplot as plt
Adult_training_outliers = Adult_trainingDF.age
Adult_training_outliers.plot.density()
plt.title('Density Plot for Age Outliers')
plt.show()

# %% [markdown]
# ### We can observe from the density plot outlier graph above that there are few outliers in the 80-90 range. The majority of the data falls between the ages of 20 and 60.

# %% [markdown]
# # Creating new data frame

# %%
#creating new dataframe for age>80
adultabove80DF= Adult_trainingDF[Adult_trainingDF['age']>80]

# %%
#Age anomaly and ploting histogram.
sns.histplot(adultabove80DF.age);

# %% [markdown]
# ## From the above histogram we can see the data lies from 80 to 90. age 90 have the highest range around 20 and least ranage of age 87.
